# %% [markdown]
# # Ejercicio 1: Utilizar operadores aritmeticos

# %%
Tierra = 149597870 
Jupiter = 778547200 

KM = Jupiter - Tierra

Millas = KM * 0.621

print(KM)
print(Millas)
# Out:
# 628949330
# 390577533.93

# %% [markdown]
# ## Ejercicio 2: convierte cadenas en números y usa valores absolutos

# %%
Planeta1 = input('Introduzca la distancia del sol para el primer planeta en KM')
Planeta2 = input('Introduzca la distancia desde el sol para el segundo planeta en KM')

Planeta1 = int(Planeta1)
Planeta2 = int(Planeta2)

distancia = Planeta2 - Planeta1

print('La distancia en km es: ' + str(distancia))

distancia_mi = distancia * 0.621
print('La distancia en millas es: ' + str(distancia_mi))
# Out:
# La distancia en km es: 456169758
# La distancia en millas es: 283281419.718
