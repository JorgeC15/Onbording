# %% [markdown]
# # Ejercicio 1: Trasnformar cadenas

# %%
text = "Interesting facts about the Moon. The Moon is Earth's only satellite. There are several interesting facts about the Moon and how it affects life here on Earth. On average, the Moon moves 4cm away from the Earth every year. This yearly drift is not significant enough to cause immediate effects on Earth. The hig"

text_partes = text.split('. ')
text_partes

palabras_clave = ["average", "temperature", "distance"]

for oracion in text_partes:
    for clave in palabras_clave:
        if clave in oracion:
            print(oracion)
        break

for sentence in text_partes:
    for claves in palabras_clave:
        if claves in sentence:
            print(sentence.replace('e', 'Celsius'))
        break
# Out:
# On average, the Moon moves 4cm away from the Earth every year
# On avCelsiusragCelsius, thCelsius Moon movCelsiuss 4cm away from thCelsius Earth CelsiusvCelsiusry yCelsiusar

# %% [markdown]
# ## Ejercicio 2: Formateando cadenas

# %%
#Datos de inicio
name = "Moon"
gravity = 0.00162 # in kms
planet = "Earth"

#Creamos el titulo
title = f'Gravedad {name}'

#Creamos la plantilla
hechos = f"""{'-' * 80}
Nombre del planeta: {planet}
Gravedad en {name}: {gravity * 1000} m/s2"""

#Unimos las cadenas
plantilla = f"""{title.title()} {hechos}"""
print(hechos)

#Nuevos datos
name = "Casa"
gravity = 9 # in kms
planet = "Marte"

Nueva_plantilla = """
Datos de Gravedad sobre: {nombre}
-------------------------------------------------------------------------------
Nombre del planeta: {planeta}
Gravedad en {nombre}: {gravedad} m/s2"""

print(Nueva_plantilla.format(nombre=name, planeta=planet, gravedad=gravity))
# Out:
# --------------------------------------------------------------------------------
# Nombre del planeta: Earth
# Gravedad en Moon: 1.6199999999999999 m/s2
#
# Datos de Gravedad sobre: Casa
# -------------------------------------------------------------------------------
# Nombre del planeta: Marte
# Gravedad en Casa: 9 m/s2
