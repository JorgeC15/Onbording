# %% [markdown]
# # Problema 01

# %%
asteroide = 49
if asteroide > 25:
    print ('Asteroide con grandes velocidades')
else:
    print ('No pasa nada')

# %% [markdown]
# ## Problema 02

# %%
asteroide2 = 90
if asteroide2 > 20:
    print('Mira hacia arriba!!')
elif asteroide2 == 20:
    print('Mira hacia arriba!!')
else:
    print('No hay nada que ver, sigue tú camino')
# Out:
# Mira hacia arriba!!

# %% [markdown]
# # Problema 03

# %%
velocidad_as = 25
tamaño_as = 40

if tamaño_as > 25 and velocidad_as > 25:
    print('¡¡¡Corraaaaaaan!!! un super asteroide')
elif velocidad_as >= 20:
    print('Mira hacia arriba!!!')
elif tamaño_as < 25:
    print('No hay problema')
else:
    print('No hay nada que ver')
# Out:
# Mira hacia arriba!!!
